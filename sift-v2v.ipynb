# %%
from ultralytics import YOLO

def download_and_load_yolo():
    try:
        print("Attempting to load YOLO model...")
        model = YOLO('yolov8n.pt')
        print("Model loaded successfully!")
        return model
    except FileNotFoundError:
        print("Model not found locally, downloading...")
        # Alternative download method
        import torch
        torch.hub.download_url_to_file(
            'https://github.com/ultralytics/assets/releases/download/v0.0.0/yolov8n.pt',
            'yolov8n.pt'
        )
        print("Download completed, loading model...")
        model = YOLO('yolov8n.pt')
        return model

# Use the function
model = download_and_load_yolo()
# Out:
# Attempting to load YOLO model...
# Model loaded successfully!

# %%
import cv2
import numpy as np
import torch
from ultralytics import YOLO
import supervision as sv
from collections import defaultdict
import tkinter as tk
from tkinter import ttk
import datetime
import argparse
import os

# %%
class TimeSelector:
    def __init__(self, video_path1, video_path2):
        self.root = tk.Tk()
        self.root.title("Video Time Selector")
        
        # Get video durations using OpenCV
        cap = cv2.VideoCapture(video_path1)
        fps = cap.get(cv2.CAP_PROP_FPS)
        frame_count = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        self.duration = int(frame_count / fps)
        cap.release()
        
        # Variables to store selected times
        self.start_time = tk.StringVar(value="00:00:00")
        self.end_time = tk.StringVar(value=self._format_time(self.duration))
        
        self._create_widgets()
        
    def _format_time(self, seconds):
        """Convert seconds to HH:MM:SS format"""
        return str(datetime.timedelta(seconds=seconds))
    
    def _parse_time(self, time_str):
        """Convert HH:MM:SS to seconds"""
        h, m, s = map(int, time_str.split(':'))
        return h * 3600 + m * 60 + s
    
    def _create_widgets(self):
        # Start time selection
        ttk.Label(self.root, text="Start Time (HH:MM:SS):").grid(row=0, column=0, padx=5, pady=5)
        ttk.Entry(self.root, textvariable=self.start_time).grid(row=0, column=1, padx=5, pady=5)
        
        # End time selection
        ttk.Label(self.root, text="End Time (HH:MM:SS):").grid(row=1, column=0, padx=5, pady=5)
        ttk.Entry(self.root, textvariable=self.end_time).grid(row=1, column=1, padx=5, pady=5)
        
        # Duration display
        ttk.Label(self.root, text=f"Video Duration: {self._format_time(self.duration)}").grid(
            row=2, column=0, columnspan=2, pady=10)
        
        # OK button
        ttk.Button(self.root, text="OK", command=self.root.quit).grid(
            row=3, column=0, columnspan=2, pady=10)
        
    def get_times(self):
        """Return selected start and end times in seconds"""
        self.root.mainloop()
        self.root.destroy()
        return (self._parse_time(self.start_time.get()),
                self._parse_time(self.end_time.get()))

class MultiViewObjectTracker:
    def __init__(self, yolo_model="yolov8n.pt"):
        # Initialize YOLO model for object detection
        self.model = YOLO(yolo_model)
        # Initialize SIFT detector
        self.sift = cv2.SIFT_create()
        # FLANN matcher
        FLANN_INDEX_KDTREE = 1
        index_params = dict(algorithm=FLANN_INDEX_KDTREE, trees=5)
        search_params = dict(checks=50)
        self.flann = cv2.FlannBasedMatcher(index_params, search_params)
        
    def detect_objects(self, frame):
        """Detect objects using YOLO"""
        results = self.model(frame)[0]
        
        # Create a custom Detections class to hold the results
        class Detections:
            def __init__(self, boxes, confidences, class_ids):
                self.xyxy = boxes
                self.confidence = confidences
                self.class_id = class_ids
        
        # Extract detection information directly from YOLO results
        if hasattr(results.boxes, 'xyxy'):
            boxes = results.boxes.xyxy.cpu().numpy()
            confidences = results.boxes.conf.cpu().numpy()
            class_ids = results.boxes.cls.cpu().numpy().astype(int)
        else:
            # If no detections, return empty arrays
            boxes = np.array([])
            confidences = np.array([])
            class_ids = np.array([])
        
        return Detections(boxes, confidences, class_ids)
    
    def extract_object_features(self, frame, bbox):
        """Extract SIFT features for an object"""
        try:
            x1, y1, x2, y2 = map(int, bbox)
            obj_img = frame[y1:y2, x1:x2]
            if obj_img.size == 0:
                return None, None
            gray = cv2.cvtColor(obj_img, cv2.COLOR_BGR2GRAY)
            keypoints, descriptors = self.sift.detectAndCompute(gray, None)
            return keypoints, descriptors
        except Exception as e:
            print(f"Error in feature extraction: {e}")
            return None, None
    
    def match_objects_between_views(self, frame1, frame2, detections1, detections2):
        """Match objects between two views and estimate depths"""
        depths = []
        
        if len(detections1.xyxy) == 0 or len(detections2.xyxy) == 0:
            return depths
        
        for i, (bbox1, conf1, class_id1) in enumerate(zip(detections1.xyxy, 
                                                         detections1.confidence, 
                                                         detections1.class_id)):
            # Extract features for object in first view
            kp1, desc1 = self.extract_object_features(frame1, bbox1)
            if kp1 is None or len(kp1) < 4:
                continue
                
            best_match = None
            min_dist = float('inf')
            matched_idx = -1
            
            # Compare with all objects of same class in second view
            for j, (bbox2, conf2, class_id2) in enumerate(zip(detections2.xyxy, 
                                                             detections2.confidence, 
                                                             detections2.class_id)):
                if class_id1 != class_id2:
                    continue
                    
                kp2, desc2 = self.extract_object_features(frame2, bbox2)
                if kp2 is None or len(kp2) < 4:
                    continue
                
                try:
                    # Match features
                    matches = self.flann.knnMatch(desc1, desc2, k=2)
                    
                    # Apply Lowe's ratio test
                    good_matches = []
                    for m, n in matches:
                        if m.distance < 0.7 * n.distance:
                            good_matches.append(m)
                    
                    if len(good_matches) < 4:
                        continue
                    
                    # Calculate average distance between matched features
                    total_dist = 0
                    for match in good_matches:
                        pt1 = kp1[match.queryIdx].pt
                        pt2 = kp2[match.trainIdx].pt
                        total_dist += np.sqrt((pt1[0] - pt2[0])**2 + (pt1[1] - pt2[1])**2)
                    avg_dist = total_dist / len(good_matches)
                    
                    if avg_dist < min_dist:
                        min_dist = avg_dist
                        best_match = bbox2
                        matched_idx = j
                        
                except Exception as e:
                    print(f"Error in matching: {e}")
                    continue
            
            if best_match is not None:
                # Calculate depth (assuming DEPTH_CONSTANT is calibrated)
                DEPTH_CONSTANT = 1000  # This should be calibrated based on your setup
                depth = DEPTH_CONSTANT / min_dist if min_dist > 0 else 0
                depths.append((bbox1, best_match, depth, class_id1))
        
        return depths
    
def process_stereo_video(video1_path, video2_path, output_path, start_time=None, end_time=None, 
                        use_gui=False):
    """
    Process stereo video with time selection
    """
    
    # Time selection
    if use_gui:
        time_selector = TimeSelector(video1_path, video2_path)
        start_time, end_time = time_selector.get_times()
    
    fourcc = cv2.VideoWriter_fourcc(*'XVID')
    
    # Initialize video captures
    cap1 = cv2.VideoCapture(video1_path)
    cap2 = cv2.VideoCapture(video2_path)
    
    if not cap1.isOpened() or not cap2.isOpened():
        raise ValueError("Error opening video files")
    
    # Get video properties
    fps = int(cap1.get(cv2.CAP_PROP_FPS))
    width = int(cap1.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap1.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap1.get(cv2.CAP_PROP_FRAME_COUNT))
    
    # Calculate frame positions
    start_frame = int(start_time * fps) if start_time is not None else 0
    end_frame = int(end_time * fps) if end_time is not None else total_frames
    
    # Set starting positions
    cap1.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
    cap2.set(cv2.CAP_PROP_POS_FRAMES, start_frame)
    
    # Initialize tracker
    tracker = MultiViewObjectTracker()
    
    # Initialize video writer with proper codec and parameters
    output_width = width * 2  # Double width for side-by-side display
    output_height = height
    
    # Try different codecs
    codecs = [
        ('XVID', '.avi'),
        ('MP4V', '.mp4'),
        ('MJPG', '.avi'),
        ('H264', '.mp4')
    ]
    
    out = None
    for codec, ext in codecs:
        try:
            temp_output = f'temp_output{ext}'
            fourcc = cv2.VideoWriter_fourcc(*codec)
            out = cv2.VideoWriter(temp_output, fourcc, fps, (output_width, output_height))
            
            # Test if VideoWriter was successfully created
            if out is not None and out.isOpened():
                output_path = f"{output_path}{ext}"  # Update output path with correct extension
                print(f"Successfully created video writer with codec: {codec}")
                break
        except Exception as e:
            print(f"Failed to create video writer with codec {codec}: {e}")
            if out is not None:
                out.release()
    
    if out is None:
        raise ValueError("Could not initialize video writer with any codec")
    
    # Progress bar setup
    total_frames_to_process = end_frame - start_frame
    current_frame = 0
    
    try:
        while cap1.isOpened() and cap2.isOpened():
            ret1, frame1 = cap1.read()
            ret2, frame2 = cap2.read()
            
            if not ret1 or not ret2 or current_frame >= total_frames_to_process:
                break
            
            # Update progress
            current_frame += 1
            progress = (current_frame / total_frames_to_process) * 100
            print(f"\rProcessing: {progress:.1f}% complete", end="")
            
            # Process frames
            detections1 = tracker.detect_objects(frame1)
            detections2 = tracker.detect_objects(frame2)
            depth_matches = tracker.match_objects_between_views(frame1, frame2, 
                                                              detections1, detections2)
            
            # Draw results
            for bbox1, bbox2, depth, class_id in depth_matches:
                # Draw bounding boxes and labels in first view
                x1, y1, x2, y2 = map(int, bbox1)
                cv2.rectangle(frame1, (x1, y1), (x2, y2), (0, 255, 0), 2)
                label = f"{tracker.model.names[class_id]}: {depth:.1f}m"
                cv2.putText(frame1, label, (x1, y1-10), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
                
                # Draw bounding boxes and labels in second view
                x1, y1, x2, y2 = map(int, bbox2)
                cv2.rectangle(frame2, (x1, y1), (x2, y2), (0, 255, 0), 2)
                cv2.putText(frame2, label, (x1, y1-10), 
                           cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
            
            # Add timestamp
            current_time = start_time + (current_frame / fps)
            timestamp = f"Time: {datetime.timedelta(seconds=int(current_time))}"
            cv2.putText(frame1, timestamp, (10, 30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
            cv2.putText(frame2, timestamp, (10, 30), 
                       cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
            
            # Combine frames
            combined_frame = np.hstack((frame1, frame2))
            
            # Write frame
            out.write(combined_frame)
            
            # Display frame
            cv2.imshow('Stereo Object Detection', cv2.resize(combined_frame, (1600, 600)))
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break
            
    except Exception as e:
        print(f"\nError during processing: {e}")
        
    finally:
        # Cleanup
        cap1.release()
        cap2.release()
        out.release()
        cv2.destroyAllWindows()
        
        # Verify output file
        if os.path.exists(temp_output) and os.path.getsize(temp_output) > 0:
            import shutil
            shutil.move(temp_output, output_path)
            print(f"\nProcessing complete! Output saved to: {output_path}")
        else:
            print("\nError: Output file is invalid or empty")

# %%
# Out:
# Successfully created video writer with codec: MJPG
# Processing: 0.5% complete
# 0: 384x640 (no detections), 56.6ms
# Speed: 3.1ms preprocess, 56.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections),
8ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 20.5% complete
# 0: 384x640 (no detections), 48.2ms
# Speed: 1.5ms preprocess, 48.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 21.0% complete
# 0: 384x640 (no detections), 49.6ms
# Speed: 1.9ms preprocess, 49.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 21.5% complete
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 53.2ms
# Speed: 1.5ms preprocess, 53.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 22.0% complete
# 0: 384x640 (no detections), 55.1ms
# Speed: 1.6ms preprocess, 55.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.4ms
# Speed: 1.6ms preprocess, 54.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 22.5% complete
# 0: 384x640 1 person, 50.4ms
# Speed: 1.7ms preprocess, 50.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 52.8ms
# Speed: 1.7ms preprocess, 52.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 23.0% complete
# 0: 384x640 1 person, 52.2ms
# Speed: 1.7ms preprocess, 52.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 23.5% complete
# 0: 384x640 1 person, 47.5ms
# Speed: 2.0ms preprocess, 47.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.5ms
# Speed: 1.5ms preprocess, 50.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 24.0% complete
# 0: 384x640 1 person, 51.7ms
# Speed: 1.8ms preprocess, 51.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 49.7ms
# Speed: 1.9ms preprocess, 49.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 24.5% complete
# 0: 384x640 1 person, 44.9ms
# Speed: 1.6ms preprocess, 44.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 44.8ms
# Speed: 1.7ms preprocess, 44.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 25.0% complete
# 0: 384x640 1 person, 60.2ms
# Speed: 1.8ms preprocess, 60.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 59.0ms
# Speed: 1.8ms preprocess, 59.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 25.5% complete
# 0: 384x640 1 person, 53.3ms
# Speed: 2.1ms preprocess, 53.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.3ms
# Speed: 1.9ms preprocess, 54.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 26.0% complete
# 0: 384x640 1 person, 48.9ms
# Speed: 1.7ms preprocess, 48.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 50.0ms
# Speed: 2.0ms preprocess, 50.0ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 26.5% complete
# 0: 384x640 1 person, 59.5ms
# Speed: 2.1ms preprocess, 59.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 54.9ms
# Speed: 1.9ms preprocess, 54.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 27.0% complete
# 0: 384x640 1 person, 59.2ms
# Speed: 1.9ms preprocess, 59.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 60.7ms
# Speed: 1.8ms preprocess, 60.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 27.5% complete
# 0: 384x640 1 person, 57.0ms
# Speed: 2.1ms preprocess, 57.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 57.8ms
# Speed: 1.9ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 28.0% complete
# 0: 384x640 1 person, 56.8ms
# Speed: 2.2ms preprocess, 56.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 56.4ms
# Speed: 1.8ms preprocess, 56.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 28.5% complete
# 0: 384x640 1 person, 48.4ms
# Speed: 1.5ms preprocess, 48.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.5ms
# Speed: 1.6ms preprocess, 47.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 29.0% complete
# 0: 384x640 1 person, 53.8ms
# Speed: 2.7ms preprocess, 53.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.7ms
# Speed: 1.8ms preprocess, 55.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 29.5% complete
# 0: 384x640 1 person, 46.8ms
# Speed: 1.7ms preprocess, 46.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.6ms
# Speed: 1.9ms preprocess, 49.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 30.0% complete
# 0: 384x640 1 person, 47.7ms
# Speed: 1.8ms preprocess, 47.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.8ms
# Speed: 1.6ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 30.5% complete
# 0: 384x640 1 person, 62.4ms
# Speed: 1.8ms preprocess, 62.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.1ms
# Speed: 2.0ms preprocess, 59.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 31.0% complete
# 0: 384x640 1 person, 51.8ms
# Speed: 1.6ms preprocess, 51.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.2ms
# Speed: 1.5ms preprocess, 48.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 31.5% complete
# 0: 384x640 1 person, 1 skateboard, 48.0ms
# Speed: 1.7ms preprocess, 48.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.1ms
# Speed: 1.7ms preprocess, 48.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 32.0% complete
# 0: 384x640 1 person, 54.4ms
# Speed: 2.1ms preprocess, 54.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.8ms
# Speed: 1.9ms preprocess, 48.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 32.5% complete
# 0: 384x640 1 person, 51.8ms
# Speed: 1.7ms preprocess, 51.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.3ms
# Speed: 1.6ms preprocess, 47.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 33.0% complete
# 0: 384x640 1 person, 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 33.5% complete
# 0: 384x640 1 person, 50.1ms
# Speed: 1.7ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.4ms
# Speed: 1.7ms preprocess, 55.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 34.0% complete
# 0: 384x640 1 person, 49.1ms
# Speed: 1.9ms preprocess, 49.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.5ms
# Speed: 1.6ms preprocess, 49.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 34.5% complete
# 0: 384x640 1 person, 46.7ms
# Speed: 1.6ms preprocess, 46.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.2ms
# Speed: 1.7ms preprocess, 47.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 35.0% complete
# 0: 384x640 1 person, 47.6ms
# Speed: 1.6ms preprocess, 47.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.0ms
# Speed: 1.8ms preprocess, 48.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 35.5% complete
# 0: 384x640 1 person, 46.8ms
# Speed: 1.8ms preprocess, 46.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 81.4ms
# Speed: 1.7ms preprocess, 81.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 36.0% complete
# 0: 384x640 1 person, 77.7ms
# Speed: 2.5ms preprocess, 77.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.7ms
# Speed: 2.3ms preprocess, 56.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 36.5% complete
# 0: 384x640 1 person, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.6ms
# Speed: 2.0ms preprocess, 51.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 37.0% complete
# 0: 384x640 1 person, 52.6ms
# Speed: 1.8ms preprocess, 52.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.1ms
# Speed: 2.3ms preprocess, 53.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 37.5% complete
# 0: 384x640 1 person, 54.1ms
# Speed: 2.0ms preprocess, 54.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.4ms
# Speed: 1.7ms preprocess, 52.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 38.0% complete
# 0: 384x640 1 person, 51.9ms
# Speed: 1.7ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.8ms
# Speed: 1.9ms preprocess, 50.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 38.5% complete
# 0: 384x640 1 person, 56.0ms
# Speed: 1.9ms preprocess, 56.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 57.0ms
# Speed: 1.7ms preprocess, 57.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 39.0% complete
# 0: 384x640 1 person, 53.2ms
# Speed: 2.0ms preprocess, 53.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.9ms
# Speed: 2.0ms preprocess, 50.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 39.5% complete
# 0: 384x640 1 person, 54.8ms
# Speed: 2.1ms preprocess, 54.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.9ms
# Speed: 1.8ms preprocess, 52.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 40.0% complete
# 0: 384x640 1 person, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.9ms
# Speed: 1.9ms preprocess, 51.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 40.5% complete
# 0: 384x640 1 person, 54.1ms
# Speed: 2.1ms preprocess, 54.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.2ms
# Speed: 1.8ms preprocess, 51.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 41.0% complete
# 0: 384x640 2 persons, 52.6ms
# Speed: 1.7ms preprocess, 52.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.5ms
# Speed: 1.7ms preprocess, 53.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 41.5% complete
# 0: 384x640 1 person, 50.0ms
# Speed: 1.6ms preprocess, 50.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.0ms
# Speed: 1.8ms preprocess, 53.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 42.0% complete
# 0: 384x640 1 person, 49.1ms
# Speed: 1.7ms preprocess, 49.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.0ms
# Speed: 1.8ms preprocess, 51.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 42.5% complete
# 0: 384x640 1 person, 52.2ms
# Speed: 1.7ms preprocess, 52.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 53.5ms
# Speed: 2.2ms preprocess, 53.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 43.0% complete
# 0: 384x640 1 person, 50.1ms
# Speed: 1.8ms preprocess, 50.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.8ms
# Speed: 1.9ms preprocess, 51.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 43.5% complete
# 0: 384x640 1 person, 54.2ms
# Speed: 2.5ms preprocess, 54.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.1ms
# Speed: 1.8ms preprocess, 50.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 44.0% complete
# 0: 384x640 1 person, 52.9ms
# Speed: 2.0ms preprocess, 52.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.4ms
# Speed: 2.0ms preprocess, 48.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 44.5% complete
# 0: 384x640 1 person, 48.4ms
# Speed: 1.7ms preprocess, 48.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.4ms
# Speed: 1.7ms preprocess, 48.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 45.0% complete
# 0: 384x640 1 person, 48.6ms
# Speed: 2.0ms preprocess, 48.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 49.4ms
# Speed: 1.6ms preprocess, 49.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 45.5% complete
# 0: 384x640 1 person, 50.2ms
# Speed: 1.7ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.7ms
# Speed: 1.8ms preprocess, 49.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 46.0% complete
# 0: 384x640 1 person, 47.5ms
# Speed: 1.8ms preprocess, 47.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 46.5ms
# Speed: 1.4ms preprocess, 46.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 46.5% complete
# 0: 384x640 1 person, 55.6ms
# Speed: 1.7ms preprocess, 55.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 52.8ms
# Speed: 2.1ms preprocess, 52.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 47.0% complete
# 0: 384x640 1 person, 50.1ms
# Speed: 1.7ms preprocess, 50.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.1ms
# Speed: 1.7ms preprocess, 47.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 47.5% complete
# 0: 384x640 1 person, 48.6ms
# Speed: 1.7ms preprocess, 48.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 45.4ms
# Speed: 1.7ms preprocess, 45.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 48.0% complete
# 0: 384x640 1 person, 53.8ms
# Speed: 2.3ms preprocess, 53.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.4ms
# Speed: 1.8ms preprocess, 48.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 48.5% complete
# 0: 384x640 1 person, 52.5ms
# Speed: 2.3ms preprocess, 52.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 51.7ms
# Speed: 2.4ms preprocess, 51.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 49.0% complete
# 0: 384x640 1 person, 49.5ms
# Speed: 1.9ms preprocess, 49.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.0ms
# Speed: 1.8ms preprocess, 56.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 49.5% complete
# 0: 384x640 1 person, 54.2ms
# Speed: 1.7ms preprocess, 54.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 55.7ms
# Speed: 2.3ms preprocess, 55.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 50.0% complete
# 0: 384x640 1 person, 47.8ms
# Speed: 1.7ms preprocess, 47.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.0ms
# Speed: 1.9ms preprocess, 47.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 50.5% complete
# 0: 384x640 3 persons, 48.3ms
# Speed: 1.8ms preprocess, 48.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 48.9ms
# Speed: 1.7ms preprocess, 48.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 51.0% complete
# 0: 384x640 2 persons, 55.0ms
# Speed: 1.8ms preprocess, 55.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 56.1ms
# Speed: 2.0ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 51.5% complete
# 0: 384x640 1 person, 49.6ms
# Speed: 1.6ms preprocess, 49.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 58.7ms
# Speed: 1.8ms preprocess, 58.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing:
2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 62.0% complete
# 0: 384x640 2 persons, 1 bicycle, 49.0ms
# Speed: 2.1ms preprocess, 49.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 50.9ms
# Speed: 1.8ms preprocess, 50.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 62.5% complete
# 0: 384x640 2 persons, 1 bicycle, 45.1ms
# Speed: 2.3ms preprocess, 45.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 47.9ms
# Speed: 1.9ms preprocess, 47.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 63.0% complete
# 0: 384x640 2 persons, 1 bicycle, 53.1ms
# Speed: 2.1ms preprocess, 53.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 59.5ms
# Speed: 2.0ms preprocess, 59.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 63.5% complete
# 0: 384x640 2 persons, 1 bicycle, 133.9ms
# Speed: 5.7ms preprocess, 133.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.1ms
# Speed: 2.0ms preprocess, 48.1ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 64.0% complete
# 0: 384x640 2 persons, 1 bicycle, 49.4ms
# Speed: 1.7ms preprocess, 49.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.1ms
# Speed: 1.7ms preprocess, 49.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 64.5% complete
# 0: 384x640 2 persons, 1 bicycle, 47.5ms
# Speed: 3.0ms preprocess, 47.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 53.1ms
# Speed: 1.7ms preprocess, 53.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 65.0% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 88.1ms
# Speed: 1.9ms preprocess, 88.1ms inference, 4.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 108.0ms
# Speed: 4.5ms preprocess, 108.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 65.5% complete
# 0: 384x640 1 person, 1 bicycle, 1 airplane, 49.6ms
# Speed: 1.8ms preprocess, 49.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 51.7ms
# Speed: 1.8ms preprocess, 51.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 66.0% complete
# 0: 384x640 1 person, 1 bicycle, 2 airplanes, 121.5ms
# Speed: 1.9ms preprocess, 121.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 88.3ms
# Speed: 1.9ms preprocess, 88.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 66.5% complete
# 0: 384x640 1 person, 1 bicycle, 106.7ms
# Speed: 4.5ms preprocess, 106.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 49.6ms
# Speed: 1.8ms preprocess, 49.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 67.0% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 46.6ms
# Speed: 1.8ms preprocess, 46.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 48.6ms
# Speed: 1.8ms preprocess, 48.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 67.5% complete
# 0: 384x640 2 persons, 1 bicycle, 49.8ms
# Speed: 1.9ms preprocess, 49.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 130.4ms
# Speed: 1.8ms preprocess, 130.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 68.0% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 68.5% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 48.3ms
# Speed: 1.8ms preprocess, 48.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 50.2ms
# Speed: 1.9ms preprocess, 50.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 69.0% complete
# 0: 384x640 2 persons, 2 bicycles, 1 airplane, 52.2ms
# Speed: 1.9ms preprocess, 52.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 53.9ms
# Speed: 2.1ms preprocess, 53.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 69.5% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 84.7ms
# Speed: 4.0ms preprocess, 84.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 52.0ms
# Speed: 1.9ms preprocess, 52.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 70.0% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 51.8ms
# Speed: 1.9ms preprocess, 51.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 53.8ms
# Speed: 2.0ms preprocess, 53.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 70.5% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 60.8ms
# Speed: 1.9ms preprocess, 60.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 57.4ms
# Speed: 2.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 71.0% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 54.4ms
# Speed: 2.2ms preprocess, 54.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 126.8ms
# Speed: 2.0ms preprocess, 126.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 71.5% complete
# 0: 384x640 2 persons, 1 bicycle, 1 airplane, 65.4ms
# Speed: 2.1ms preprocess, 65.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 57.0ms
# Speed: 2.6ms preprocess, 57.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 72.0% complete
# 0: 384x640 4 persons, 1 bicycle, 1 airplane, 74.4ms
# Speed: 4.5ms preprocess, 74.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 53.7ms
# Speed: 1.6ms preprocess, 53.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 72.5% complete
# 0: 384x640 2 persons, 1 airplane, 111.6ms
# Speed: 6.9ms preprocess, 111.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 55.2ms
# Speed: 1.8ms preprocess, 55.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 73.0% complete
# 0: 384x640 2 persons, 1 airplane, 116.5ms
# Speed: 2.2ms preprocess, 116.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 90.0ms
# Speed: 5.5ms preprocess, 90.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 73.5% complete
# 0: 384x640 2 persons, 1 airplane, 54.6ms
# Speed: 2.1ms preprocess, 54.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 56.6ms
# Speed: 1.9ms preprocess, 56.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 74.0% complete
# 0: 384x640 2 persons, 1 airplane, 53.4ms
# Speed: 2.1ms preprocess, 53.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 54.5ms
# Speed: 1.9ms preprocess, 54.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 74.5% complete
# 0: 384x640 1 person, 1 airplane, 54.6ms
# Speed: 1.8ms preprocess, 54.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 54.6ms
# Speed: 1.7ms preprocess, 54.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 75.0% complete
# 0: 384x640 2 persons, 52.6ms
# Speed: 1.9ms preprocess, 52.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 75.5% complete
# 0: 384x640 1 person, 51.8ms
# Speed: 1.9ms preprocess, 51.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 51.7ms
# Speed: 1.8ms preprocess, 51.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 76.0% complete
# 0: 384x640 1 person, 52.2ms
# Speed: 1.8ms preprocess, 52.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 57.6ms
# Speed: 2.2ms preprocess, 57.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 76.5% complete
# 0: 384x640 1 person, 51.5ms
# Speed: 1.9ms preprocess, 51.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 53.7ms
# Speed: 1.9ms preprocess, 53.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 77.0% complete
# 0: 384x640 1 person, 52.0ms
# Speed: 1.8ms preprocess, 52.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 traffic light, 53.3ms
# Speed: 2.3ms preprocess, 53.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 77.5% complete
# 0: 384x640 1 person, 52.3ms
# Speed: 1.9ms preprocess, 52.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 traffic light, 55.2ms
# Speed: 2.1ms preprocess, 55.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 78.0% complete
# 0: 384x640 1 person, 59.0ms
# Speed: 2.1ms preprocess, 59.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.2ms
# Speed: 1.9ms preprocess, 58.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 78.5% complete
# 0: 384x640 1 person, 52.9ms
# Speed: 1.9ms preprocess, 52.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 airplane, 52.5ms
# Speed: 1.9ms preprocess, 52.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 79.0% complete
# 0: 384x640 1 person, 51.5ms
# Speed: 1.8ms preprocess, 51.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 54.8ms
# Speed: 2.1ms preprocess, 54.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 79.5% complete
# 0: 384x640 1 person, 67.6ms
# Speed: 2.1ms preprocess, 67.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 1 airplane, 60.1ms
# Speed: 2.1ms preprocess, 60.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 80.0% complete
# 0: 384x640 1 person, 65.9ms
# Speed: 2.0ms preprocess, 65.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 airplane, 65.5ms
# Speed: 2.2ms preprocess, 65.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 80.5% complete
# 0: 384x640 1 person, 59.3ms
# Speed: 2.1ms preprocess, 59.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 airplane, 61.9ms
# Speed: 1.9ms preprocess, 61.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 81.0% complete
# 0: 384x640 1 person, 57.5ms
# Speed: 2.3ms preprocess, 57.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 airplane, 56.8ms
# Speed: 1.9ms preprocess, 56.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 81.5% complete
# 0: 384x640 1 person, 57.0ms
# Speed: 1.7ms preprocess, 57.0ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 55.1ms
# Speed: 1.8ms preprocess, 55.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 82.0% complete
# 0: 384x640 1 person, 54.9ms
# Speed: 1.9ms preprocess, 54.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 82.5% complete
# 0: 384x640 1 person, 56.9ms
# Speed: 1.9ms preprocess, 56.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 58.2ms
# Speed: 1.9ms preprocess, 58.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 83.0% complete
# 0: 384x640 1 person, 58.4ms
# Speed: 2.2ms preprocess, 58.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 58.9ms
# Speed: 1.9ms preprocess, 58.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 83.5% complete
# 0: 384x640 (no detections), 55.3ms
# Speed: 1.9ms preprocess, 55.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 56.1ms
# Speed: 2.2ms preprocess, 56.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 84.0% complete
# 0: 384x640 (no detections), 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 60.8ms
# Speed: 2.1ms preprocess, 60.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 84.5% complete
# 0: 384x640 (no detections), 58.4ms
# Speed: 1.9ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 57.8ms
# Speed: 2.3ms preprocess, 57.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 85.0% complete
# 0: 384x640 (no detections), 55.0ms
# Speed: 1.9ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 64.2ms
# Speed: 2.1ms preprocess, 64.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 85.5% complete
# 0: 384x640 (no detections), 64.7ms
# Speed: 2.5ms preprocess, 64.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 65.5ms
# Speed: 2.3ms preprocess, 65.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 86.0% complete
# 0: 384x640 1 person, 66.9ms
# Speed: 2.6ms preprocess, 66.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 86.5% complete
# 0: 384x640 1 person, 66.8ms
# Speed: 2.1ms preprocess, 66.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 70.5ms
# Speed: 2.6ms preprocess, 70.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 87.0% complete
# 0: 384x640 1 person, 60.1ms
# Speed: 2.3ms preprocess, 60.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 airplanes, 62.1ms
# Speed: 2.2ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 87.5% complete
# 0: 384x640 1 person, 61.9ms
# Speed: 2.1ms preprocess, 61.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 airplanes, 58.8ms
# Speed: 2.2ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 88.0% complete
# 0: 384x640 1 person, 53.9ms
# Speed: 1.8ms preprocess, 53.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 2 airplanes, 59.9ms
# Speed: 1.8ms preprocess, 59.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 88.5% complete
# 0: 384x640 2 persons, 52.4ms
# Speed: 2.0ms preprocess, 52.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 54.2ms
# Speed: 2.0ms preprocess, 54.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 89.0% complete
# 0: 384x640 2 persons, 50.6ms
# Speed: 1.8ms preprocess, 50.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 55.0ms
# Speed: 1.8ms preprocess, 55.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 89.5% complete
# 0: 384x640 2 persons, 53.0ms
# Speed: 1.9ms preprocess, 53.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 58.9ms
# Speed: 1.8ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 90.0% complete
# 0: 384x640 2 persons, 59.1ms
# Speed: 2.2ms preprocess, 59.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 60.7ms
# Speed: 1.9ms preprocess, 60.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 90.5% complete
# 0: 384x640 1 person, 69.6ms
# Speed: 2.5ms preprocess, 69.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 airplanes, 57.7ms
# Speed: 1.8ms preprocess, 57.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 91.0% complete
# 0: 384x640 1 person, 56.9ms
# Speed: 2.1ms preprocess, 56.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 54.0ms
# Speed: 1.9ms preprocess, 54.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 91.5% complete
# 0: 384x640 1 person, 54.1ms
# Speed: 1.7ms preprocess, 54.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 airplane, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 92.0% complete
# 0: 384x640 1 person, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 airplane, 59.2ms
# Speed: 1.9ms preprocess, 59.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 92.5% complete
# 0: 384x640 1 person, 64.4ms
# Speed: 1.9ms preprocess, 64.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 1 airplane, 71.4ms
# Speed: 2.1ms preprocess, 71.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 93.0% complete
# 0: 384x640 1 person, 60.1ms
# Speed: 2.0ms preprocess, 60.1ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 airplane, 58.9ms
# Speed: 1.9ms preprocess, 58.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 93.5% complete
# 0: 384x640 1 person, 61.4ms
# Speed: 1.7ms preprocess, 61.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.5ms
# Speed: 1.8ms preprocess, 58.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 94.0% complete
# 0: 384x640 1 person, 57.3ms
# Speed: 1.9ms preprocess, 57.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.7ms
# Speed: 1.9ms preprocess, 60.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 94.5% complete
# 0: 384x640 1 person, 54.8ms
# Speed: 2.1ms preprocess, 54.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.7ms
# Speed: 2.2ms preprocess, 59.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 95.0% complete
# 0: 384x640 2 persons, 120.3ms
# Speed: 2.4ms preprocess, 120.3ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 84.0ms
# Speed: 3.0ms preprocess, 84.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 95.5% complete
# 0: 384x640 1 person, 74.1ms
# Speed: 2.5ms preprocess, 74.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 skateboard, 68.8ms
# Speed: 2.3ms preprocess, 68.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 96.0% complete
# 0: 384x640 2 persons, 61.7ms
# Speed: 2.2ms preprocess, 61.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.7ms
# Speed: 2.3ms preprocess, 59.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 96.5% complete
# 0: 384x640 1 person, 58.4ms
# Speed: 2.0ms preprocess, 58.4ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 97.0% complete
# 0: 384x640 2 persons, 65.2ms
# Speed: 2.2ms preprocess, 65.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 60.6ms
# Speed: 2.2ms preprocess, 60.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 97.5% complete
# 0: 384x640 1 person, 61.0ms
# Speed: 2.2ms preprocess, 61.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 58.0ms
# Speed: 2.1ms preprocess, 58.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 98.0% complete
# 0: 384x640 1 person, 57.0ms
# Speed: 2.1ms preprocess, 57.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 98.5% complete
# 0: 384x640 2 persons, 63.8ms
# Speed: 2.2ms preprocess, 63.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 122.4ms
# Speed: 2.4ms preprocess, 122.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 99.0% complete
# 0: 384x640 1 person, 67.3ms
# Speed: 2.3ms preprocess, 67.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 61.7ms
# Speed: 1.9ms preprocess, 61.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 99.5% complete
# 0: 384x640 2 persons, 71.5ms
# Speed: 2.5ms preprocess, 71.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 62.0ms
# Speed: 2.1ms preprocess, 62.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 100.0% complete
# 0: 384x640 2 persons, 56.4ms
# Speed: 2.2ms preprocess, 56.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 69.8ms
# Speed: 2.3ms preprocess, 69.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# Processing complete! Output saved to: stereo_output.avi
